# %% [markdown]
# # Importing data

# %%
import pandas as pd
import matplotlib.pyplot as plt


data_2243 = pd.read_excel('HR-Given.xlsx', sheet_name = '2243')
data_6231 = pd.read_excel('HR-Given.xlsx', sheet_name = '6231')

# data_2243 = pd.read_csv('ngc2243.dat', names = [['Image', '??', 'V', 'B-V']])
# data_6231 = pd.read_csv('ngc6231.dat')

# %% [markdown]
# ## Viewing data
#
# ** Data given is V en B-V

# %%
#data_6231['V'] = data_6231['B'] + data_6231['B-V']
len(data_6231)
# Out:
# 1900

# %% [markdown]
# ### Plotting CMD (color-magnitude Diagram)

# %%
plt.figure(figsize= (10,8))

ax = plt.gca()
ax.invert_yaxis()


plt.title('CMD of Cluster 6231', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')


plt.legend()
plt.grid()

# %% [markdown]
# # Data from CMD sites

# %% [markdown]
# ## From 3.6
#
# colNames = ['Zini','MH','logAge','Mini','int_IMF','Mass','logL','logTe','logg','label','McoreTP', 'C_O', 'period0','period1' , 'period2','period3','period4','pmode','Mloss','tau1m','X','Y','Xc','Xn','Xo','Cexcess' , 'Z','mbolmag','Umag','Bmag','Vmag','Rmag','Imag','Jmag','Hmag','Kmag']

# %% [markdown]
# #### Testing

# %%
#colNames = ['Zini','MH','logAge','Mini','int_IMF','Mass','logL','logTe','logg','label','McoreTP', 'C_O', 'period0','period1' , 'period2','period3','period4','pmode','Mloss','tau1m','X','Y','Xc','Xn','Xo','Cexcess' , 'Z','mbolmag','Umag','Bmag','Vmag','Rmag','Imag','Jmag','Hmag','Kmag']
dropNames = ['Zini','MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg',
       'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3',
       'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo',
       'Cexcess', 'Umag', 'Rmag', 'Imag', 'Jmag', 'Hmag','Kmag']

df = pd.read_csv('output3.dat.txt', delim_whitespace= True, skiprows=13)
df1 = df.drop(dropNames, axis=1)
#df.columns

df1['B-V'] = df1['Bmag'] - df1['Vmag']
df1.head()
# Out:
#          Z  mbolmag    Bmag    Vmag    B-V
# 0  0.01527    9.941  15.776  14.300  1.476
# 1  0.01527    9.783  15.625  14.147  1.478
# 2  0.01527    9.780  15.621  14.143  1.478
# 3  0.01527    9.462  15.268  13.786  1.482
# 4  0.01527    9.299  14.929  13.448  1.481

# %%
plt.figure(figsize= (10,5))

ax = plt.gca()
ax.invert_yaxis()

plt.title('output3')
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(df1['B-V'], df1['Vmag'], label = 'output3')

# %% [markdown]
# ##### Plotting two on one

# %%
plt.figure(figsize= (10,5))

ax = plt.gca()
ax.invert_yaxis()

plt.title('output3')
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(df1['B-V'], df1['Vmag'], label = 'output3')

plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')

# %% [markdown]
# ### Same AGE's, differnt Z

# %% [markdown]
# #### 1e6 years

# %%
dropNames = ['Zini','MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg',
       'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3',
       'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo',
       'Cexcess', 'Umag', 'Rmag', 'Imag', 'Jmag', 'Hmag','Kmag']


#--------Creating Frames for eac Z value-------------
z0_03_6  = pd.read_csv('CMD3.6\Same Age[1e6]\Z_0.03.dat', delim_whitespace=True, skiprows=13)
z0_019_6 = pd.read_csv('CMD3.6\Same Age[1e6]\Z_0.019.dat', delim_whitespace= True, skiprows=13)
z0_010_6 = pd.read_csv('CMD3.6\Same Age[1e6]\Z_0.010.dat', delim_whitespace= True, skiprows=13)
z0_005_6 = pd.read_csv('CMD3.6\Same Age[1e6]\Z_0.005.dat', delim_whitespace= True, skiprows=13)
z0_001_6 = pd.read_csv('CMD3.6\Same Age[1e6]\Z_0.001.dat', delim_whitespace= True, skiprows=13)


#-------Dropping unneeded coloms--------
z0_03_6 =  z0_03_6.drop(dropNames, axis=1)
z0_019_6 = z0_019_6.drop(dropNames, axis=1)
z0_010_6 = z0_010_6.drop(dropNames, axis=1)
z0_005_6 = z0_005_6.drop(dropNames, axis=1)
z0_001_6 = z0_001_6.drop(dropNames, axis=1)


#------------Creating Diff col -----------
z0_03_6['B-V'] = z0_03_6['Bmag'] - z0_03_6['Vmag']
z0_019_6['B-V'] = z0_019_6['Bmag'] - z0_019_6['Vmag']
z0_010_6['B-V'] = z0_010_6['Bmag'] - z0_010_6['Vmag']
z0_005_6['B-V'] = z0_005_6['Bmag'] - z0_005_6['Vmag']
z0_001_6['B-V'] = z0_001_6['Bmag'] - z0_001_6['Vmag']

#======-----Graphing differnt Z vlaues-----=======
plt.figure(figsize= (10,8))

ax = plt.gca()
ax.invert_yaxis()

plt.title('Same age [1e6]')
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)



plt.scatter(z0_03_6['B-V'], z0_03_6['Vmag'], label = '0.03')
plt.scatter(z0_019_6['B-V'], z0_019_6['Vmag'], label = '0.019')
plt.scatter(z0_010_6['B-V'], z0_010_6['Vmag'], label = '0.010')
plt.scatter(z0_005_6['B-V'], z0_005_6['Vmag'], label = '0.005')
plt.scatter(z0_001_6['B-V'], z0_001_6['Vmag'], label = '0.001')

plt.legend(loc = 'right')

z0_005_6.head()

# with pd.ExcelWriter('age_6_diff_metal.xlsx', mode='w') as writer:  
#     z0_03_6.to_excel( writer, sheet_name = 'Z_03')
#     z0_019_6.to_excel(writer , sheet_name = 'Z_019')               
#     z0_010_6.to_excel(writer , sheet_name = 'Z_010')                                 
#     z0_005_6.to_excel(writer , sheet_name = 'Z_005')               
#     z0_001_6.to_excel(writer , sheet_name = 'Z_001')               

len(z0_03_6['B-V'])
# Out:
# 298

# %% [markdown]
# #### 1e7 Years

# %%
#--------Creating Frames for eac Z value-------------
z0_03_7  = pd.read_csv('CMD3.6\Same Age[1e7]\Z_0.03.dat', delim_whitespace = True, skiprows=13)
z0_019_7 = pd.read_csv('CMD3.6\Same Age[1e7]\Z_0.019.dat', delim_whitespace= True, skiprows=13)
z0_010_7 = pd.read_csv('CMD3.6\Same Age[1e7]\Z_0.010.dat', delim_whitespace= True, skiprows=13)
z0_005_7 = pd.read_csv('CMD3.6\Same Age[1e7]\Z_0.005.dat', delim_whitespace= True, skiprows=13)
z0_001_7 = pd.read_csv('CMD3.6\Same Age[1e7]\Z_0.001.dat', delim_whitespace= True, skiprows=13)

#-------Dropping unneeded coloms--------
z0_03_7 =  z0_03_7.drop(dropNames, axis=1)
z0_019_7 = z0_019_7.drop(dropNames, axis=1)
z0_010_7 = z0_010_7.drop(dropNames, axis=1)
z0_005_7 = z0_005_7.drop(dropNames, axis=1)
z0_001_7 = z0_001_7.drop(dropNames, axis=1)

#------------Creating Diff col -----------
z0_03_7['B-V'] = z0_03_7['Bmag'] - z0_03_7['Vmag']
z0_019_7['B-V'] = z0_019_7['Bmag'] - z0_019_7['Vmag']
z0_010_7['B-V'] = z0_010_7['Bmag'] - z0_010_7['Vmag']
z0_005_7['B-V'] = z0_005_7['Bmag'] - z0_005_7['Vmag']
z0_001_7['B-V'] = z0_001_7['Bmag'] - z0_001_7['Vmag']

#======-----Graphing differnt Z vlaues-----=======
plt.figure(figsize= (10,8))

ax = plt.gca()
ax.invert_yaxis()

plt.title('Same age [1e7]')
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)



plt.scatter(z0_03_7['B-V'], z0_03_7['Vmag'], label = '0.03')
plt.scatter(z0_019_7['B-V'], z0_019_7['Vmag'], label = '0.019')
plt.scatter(z0_010_7['B-V'], z0_010_7['Vmag'], label = '0.010')
plt.scatter(z0_005_7['B-V'], z0_005_7['Vmag'], label = '0.005')
plt.scatter(z0_001_7['B-V'], z0_001_7['Vmag'], label = '0.001')



#------======= Our Clusters =======--------
# plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')



plt.legend(loc = 'right')
plt.grid()

with pd.ExcelWriter('age_7_diff_metal.xlsx', mode='w') as writer:  
    z0_03_7.to_excel( writer, sheet_name = 'Z_03')
    z0_019_7.to_excel(writer , sheet_name = 'Z_019')               
    z0_010_7.to_excel(writer , sheet_name = 'Z_010')                                 
    z0_005_7.to_excel(writer , sheet_name = 'Z_005')               
    z0_001_7.to_excel(writer , sheet_name = 'Z_001')

# %%
plt.scatter(z0_03_7['B-V'], z0_03_7['Vmag'], label = '0.03')
#plt.scatter(z0_03_6['B-V'], z0_03_6['Vmag'], label = '0.03')

plt.legend()

# %% [markdown]
# #### 1e8 years

# %%
#colNames = ['Zini','MH','logAge','Mini','int_IMF','Mass','logL','logTe','logg','label','McoreTP', 'C_O', 'period0','period1' , 'period2','period3','period4','pmode','Mloss','tau1m','X','Y','Xc','Xn','Xo','Cexcess' , 'Z','mbolmag','Umag','Bmag','Vmag','Rmag','Imag','Jmag','Hmag','Kmag']
dropNames = ['Zini','MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg',
       'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3',
       'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo',
       'Cexcess', 'Umag', 'Rmag', 'Imag', 'Jmag', 'Hmag','Kmag']


#--------Creating Frames for eac Z value-------------
#z0_03_6  = pd.read_csv('CMD3.6/Same Age[1e6]/3.1/Z_0.03.dat', delim_whitespace=4, skiprows=8)

z0_03_8  = pd.read_csv('CMD3.6\Same Age[1e8]\Z_0.03.dat', delim_whitespace = True , skiprows=13)
z0_019_8 = pd.read_csv('CMD3.6\Same Age[1e8]\Z_0.019.dat', delim_whitespace= True , skiprows=13)
z0_010_8 = pd.read_csv('CMD3.6\Same Age[1e8]\Z_0.010.dat', delim_whitespace= True , skiprows=13)
z0_005_8 = pd.read_csv('CMD3.6\Same Age[1e8]\Z_0.005.dat', delim_whitespace= True , skiprows=13)
z0_001_8 = pd.read_csv('CMD3.6\Same Age[1e8]\Z_0.001.dat', delim_whitespace= True , skiprows=13)


#-------Dropping unneeded coloms--------
z0_03_8 =  z0_03_8.drop(dropNames, axis=1)
z0_019_8 = z0_019_8.drop(dropNames, axis=1)
z0_010_8 = z0_010_8.drop(dropNames, axis=1)
z0_005_8 = z0_005_8.drop(dropNames, axis=1)
z0_001_8 = z0_001_8.drop(dropNames, axis=1)


#------------Creating Diff col -----------
z0_03_8['B-V'] = z0_03_8['Bmag'] - z0_03_8['Vmag']
z0_019_8['B-V'] = z0_019_8['Bmag'] - z0_019_8['Vmag']
z0_010_8['B-V'] = z0_010_8['Bmag'] - z0_010_8['Vmag']
z0_005_8['B-V'] = z0_005_8['Bmag'] - z0_005_8['Vmag']
z0_001_8['B-V'] = z0_001_8['Bmag'] - z0_001_8['Vmag']

#======-----Graphing differnt Z vlaues-----=======
plt.figure(figsize= (10,8))

ax = plt.gca()
ax.invert_yaxis()

plt.title('Same age [1e8]', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)



plt.scatter(z0_03_8['B-V'], z0_03_8['Vmag'], label = '0.03')
plt.scatter(z0_019_8['B-V'], z0_019_8['Vmag'], label = '0.019')
plt.scatter(z0_010_8['B-V'], z0_010_8['Vmag'], label = '0.010')
plt.scatter(z0_005_8['B-V'], z0_005_8['Vmag'], label = '0.005')
plt.scatter(z0_001_8['B-V'], z0_001_8['Vmag'], label = '0.001')


#------======= Our Clusters =======--------
plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')

plt.legend(loc = 'right')

z0_005_8.head()



# with pd.ExcelWriter('age_8_diff_metal.xlsx', mode='w') as writer:  
#     z0_03_8.to_excel( writer, sheet_name = 'Z_03')
#     z0_019_8.to_excel(writer , sheet_name = 'Z_019')               
#     z0_010_8.to_excel(writer , sheet_name = 'Z_010')                                 
#     z0_005_8.to_excel(writer , sheet_name = 'Z_005')               
#     z0_001_8.to_excel(writer , sheet_name = 'Z_001')
# Out:
#           Z  mbolmag    Bmag    Vmag    B-V
# 0  0.005101   11.497  16.717  14.959  1.758
# 1  0.005101   11.398  16.461  14.717  1.744
# 2  0.005101   11.303  16.215  14.481  1.734
# 3  0.005101   11.229  16.038  14.313  1.725
# 4  0.005101   11.061  15.634  13.931  1.703

# %%
z0_005_8.tail()
# Out:
#             Z  mbolmag    Bmag    Vmag    B-V
# 423  0.005245   -6.501   0.301  -1.019  1.320
# 424  0.005247   -6.494   0.356  -0.957  1.313
# 425  0.005249   -6.479   0.405  -0.903  1.308
# 426  0.005252   -6.460   0.446  -0.860  1.306
# 427  0.005263   29.767  30.016  30.061 -0.045

# %% [markdown]
# #### 1e9 Years

# %% [markdown]
# #### Plottine e6 on same as 2243

# %%
#colNames = ['Zini','MH','logAge','Mini','int_IMF','Mass','logL','logTe','logg','label','McoreTP', 'C_O', 'period0','period1' , 'period2','period3','period4','pmode','Mloss','tau1m','X','Y','Xc','Xn','Xo','Cexcess' , 'Z','mbolmag','Umag','Bmag','Vmag','Rmag','Imag','Jmag','Hmag','Kmag']
dropNames = ['Zini','MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg',
       'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3',
       'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo',
       'Cexcess', 'Umag', 'Rmag', 'Imag', 'Jmag', 'Hmag','Kmag']


#--------Creating Frames for eac Z value-------------
#z0_03_6  = pd.read_csv('CMD3.6/Same Age[1e6]/3.1/Z_0.03.dat', delim_whitespace=4, skiprows=8)

## ----- Z~value __ then Year
z0_03_9  = pd.read_csv('CMD3.6\Same Age[1e9]\Z_0.03.dat', delim_whitespace = True , skiprows=13)
z0_019_9 = pd.read_csv('CMD3.6\Same Age[1e9]\Z_0.019.dat', delim_whitespace= True , skiprows=13)
z0_010_9 = pd.read_csv('CMD3.6\Same Age[1e9]\Z_0.010.dat', delim_whitespace= True , skiprows=13)
z0_005_9 = pd.read_csv('CMD3.6\Same Age[1e9]\Z_0.005.dat', delim_whitespace= True , skiprows=13)
z0_001_9 = pd.read_csv('CMD3.6\Same Age[1e9]\Z_0.001.dat', delim_whitespace= True , skiprows=13)


#-------Dropping unneeded coloms--------
z0_03_9 =  z0_03_9.drop(dropNames, axis=1)
z0_019_9 = z0_019_9.drop(dropNames, axis=1)
z0_010_9 = z0_010_9.drop(dropNames, axis=1)
z0_005_9 = z0_005_9.drop(dropNames, axis=1)
z0_001_9 = z0_001_9.drop(dropNames, axis=1)


#------------Creating Diff col -----------
z0_03_9['B-V'] = z0_03_9['Bmag'] - z0_03_9['Vmag']
z0_019_9['B-V'] = z0_019_9['Bmag'] - z0_019_9['Vmag']
z0_010_9['B-V'] = z0_010_9['Bmag'] - z0_010_9['Vmag']
z0_005_9['B-V'] = z0_005_9['Bmag'] - z0_005_9['Vmag']
z0_001_9['B-V'] = z0_001_9['Bmag'] - z0_001_9['Vmag']

#======-----Graphing differnt Z vlaues-----=======
plt.figure(figsize= (10,8))

ax = plt.gca()
ax.invert_yaxis()

plt.title('Same age [1e9]', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.grid()


plt.scatter(z0_03_9['B-V'], z0_03_9['Vmag'], label = '0.03')
plt.scatter(z0_019_9['B-V'], z0_019_9['Vmag'], label = '0.019')
plt.scatter(z0_010_9['B-V'], z0_010_9['Vmag'], label = '0.010')
plt.scatter(z0_005_9['B-V'], z0_005_9['Vmag'], label = '0.005')
plt.scatter(z0_001_9['B-V'], z0_001_9['Vmag'], label = '0.001')

plt.legend(loc = 'right')
plt.ylim(20,-5)
# z0_005_9.head()



# with pd.ExcelWriter('age_9_diff_metal.xlsx', mode='w') as writer:  
#     z0_03_9.to_excel( writer, sheet_name = 'Z_03')
#     z0_019_9.to_excel(writer , sheet_name = 'Z_019')               
#     z0_010_9.to_excel(writer , sheet_name = 'Z_010')                                 
#     z0_005_9.to_excel(writer , sheet_name = 'Z_005')               
#     z0_001_9.to_excel(writer , sheet_name = 'Z_001')
# Out:
# (20.0, -5.0)

# %%
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Same age [1e6]')
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

# Data of Age 6 with differnt metalisities
plt.scatter(z0_03_6['B-V'], z0_03_6['Vmag'], label = '0.03')
plt.scatter(z0_019_6['B-V'], z0_019_6['Vmag'], label = '0.019')
plt.scatter(z0_010_6['B-V'], z0_010_6['Vmag'], label = '0.010')
plt.scatter(z0_005_6['B-V'], z0_005_6['Vmag'], label = '0.005')
plt.scatter(z0_001_6['B-V'], z0_001_6['Vmag'], label = '0.001')


# Given data
plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')

plt.legend()

# %%
plt.scatter(z0_019_6['B-V'], z0_019_6['Vmag'], label = '0.019')
plt.scatter(z0_019_7['B-V'], z0_019_7['Vmag'], label = '0.019')

# %% [markdown]
# ### Same Metal -- Diff age

# %% [markdown]
# #### Z = 0.001

# %%
import pandas as pd
colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_001 = pd.read_csv('CMD3.6\Same Metalicity[e6-e10]\Z_001.txt', delim_whitespace= True, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_001 = z0_001.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_001[sZ_001['logAge'] == 6].astype(float)
age7 = sZ_001[sZ_001['logAge'] == 7].astype(float)
age8 = sZ_001[sZ_001['logAge'] == 8 ].astype(float)
age9 = sZ_001[sZ_001['logAge'] == 9 ].astype(float)
age10 = sZ_001[sZ_001['logAge'] == 10 ].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.001', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.legend(title = 'Years')


# with pd.ExcelWriter('Files\metal_001_diff_year.xlsx', mode='w') as writer:  
#     age6.to_excel( writer, sheet_name = 'Y6')
#     age7.to_excel(writer , sheet_name = 'Y7')               
#     age8.to_excel(writer , sheet_name = 'Y8')                                 
#     age9.to_excel(writer , sheet_name = 'Y9')               
#     age10.to_excel(writer , sheet_name = 'Y10')

# %% [markdown]
# #### Z = 0.005

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_005 = pd.read_csv('CMD3.6\Same Metalicity[e6-e10]\Z_005.dat', delim_whitespace=1, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_005 = z0_005.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_005[sZ_005['logAge'] == 6].astype(float)
age7 = sZ_005[sZ_005['logAge'] == 7].astype(float)
age8 = sZ_005[sZ_005['logAge'] == 8].astype(float)
age9 = sZ_005[sZ_005['logAge'] == 9].astype(float)
age10= sZ_005[sZ_005['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.005', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

# #------======= Our Clusters =======--------
# plt.scatter(data_2243['B-V'], data_2243['V'], label = '2243')
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')


plt.legend(title = 'Years')

# %% [markdown]
# #### Z = 0.03

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_03 = pd.read_csv('CMD3.6\Same Metalicity[e6-e10]\Z_03.dat', delim_whitespace=1, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_03 = z0_03.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_03[sZ_03['logAge'] == 6].astype(float)
age7 = sZ_03[sZ_03['logAge'] == 7].astype(float)
age8 = sZ_03[sZ_03['logAge'] == 8].astype(float)
age9 = sZ_03[sZ_03['logAge'] == 9].astype(float)
age10= sZ_03[sZ_03['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.03', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.legend(title = 'Years')

# %%
sZ_03.describe()
# Out:
#             logAge         Bmag         Vmag
# count  1985.000000  1985.000000  1985.000000
# mean      8.108816     1.805698     0.835452
# std       1.246466     4.430083     4.187135
# min       6.000000    -8.248000    -7.939000
# 25%       7.000000     0.199000    -0.935000
# 50%       8.000000     1.598000     0.396000
# 75%       9.000000     2.669000     1.783000
# max      10.000000    32.267000    32.525000

# %% [markdown]
# #### Z = 0.010

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_010 = pd.read_csv('CMD3.6\Same Metalicity[e6-e10]\Z_010.dat', delim_whitespace=1, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_010 = z0_010.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_010[sZ_010['logAge'] == '6.00000'].astype(float)
age7 = sZ_010[sZ_010['logAge'] == '7.00000'].astype(float)
age8 = sZ_010[sZ_010['logAge'] == '8.00000'].astype(float)
age9 = sZ_010[sZ_010['logAge'] == '9.00000'].astype(float)
age10= sZ_010[sZ_010['logAge'] == '10.00000'].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.010', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.legend(title = 'Years')

# %% [markdown]
# #### Z = 0.019

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_019 = pd.read_csv('CMD3.6/Same Metalicity[e6-e10]/Z_019.dat', delim_whitespace=1, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_019 = z0_019.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_019[sZ_019['logAge'] == 6 ].astype(float)
age7 = sZ_019[sZ_019['logAge'] == 7 ].astype(float)
age8 = sZ_019[sZ_019['logAge'] == 8 ].astype(float)
age9 = sZ_019[sZ_019['logAge'] == 9 ].astype(float)
age10= sZ_019[sZ_019['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.019', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.legend(title = 'Years')
plt.grid()

# %% [markdown]
# # Our Clusters

# %% [markdown]
# ### Metalicity

# %%
import math

Z0 = 0.0196

#----====== log10(z/z0) =======--------
def metal(Z):
    ans = (10**Z)*Z0
    return ans

metal(-0.44)

#print(math.log10(metal(-.44)/Z0))
# Out:
# 0.007116329873493987

# %% [markdown]
# ### 2243

# %% [markdown]
# ##### Distance Modulus.
#
# https://webda.physics.muni.cz/cgi-bin/ocl_page.cgi?dirname=ngc2243
#
# *** https://in-the-sky.org/data/object.php?id=NGC2243 ***

# %%
Mv = 9.4
mag = data_2243['V'].mean()


# /data_2243['V'].count()
# data_2243['V'].describe()


d = 10**((mag-Mv+3.2*0.72+5)/5)

print('Bolemetric mag\t:' , Mv)
print('Avrg mag\t:' , round(mag,3))
print('Avrg B-V\t:' , round(data_2243['B-V'].mean(),3))
print('m-M \t\t:' ,   round(mag-Mv,3))
print('Distance\t:' , round(d,3) , ' pc')
# Out:
# Bolemetric mag	: 9.4
# Avrg mag	: 18.138
# Avrg B-V	: 0.736
# m-M 		: 8.738
# Distance	: 1615.487  pc

# %% [markdown]
# #### Z = 0.006898
# Z0 = 0.019

# %%
from turtle import position
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_006 = pd.read_csv('CMD3.6/Cluster 2243/z_0.006_age6_10.dat', delim_whitespace=True, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_006 = z0_006.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_006[sZ_006['logAge'] == 6].astype(float)
age7 = sZ_006[sZ_006['logAge'] == 7].astype(float)
age8 = sZ_006[sZ_006['logAge'] == 8].astype(float)
age9 = sZ_006[sZ_006['logAge'] == 9].astype(float)
age10= sZ_006[sZ_006['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']



#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.006899', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

#------======= Our Clusters =======--------
plt.scatter(data_2243['B-V'] ,data_2243['V'], label = '2243', zorder = 1 )
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')

plt.scatter(age6['B-V']+0.7, age6['Vmag']+19, label = '6')
plt.scatter(age7['B-V']+0.7, age7['Vmag']+17, label = '7')
plt.scatter(age8['B-V']+0.7, age8['Vmag']+17, label = '8')
plt.scatter(age9['B-V']+0.4, age9['Vmag']+15, label = '9')
plt.scatter(age10['B-V']-.05, age10['Vmag']+13, label = '10')

# plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
# plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
# plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
# plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
# plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.grid()
plt.legend(title = 'Years', loc = 'right')
# plt.ylim(35,5)


# age6

# %%
len(age7)
# Out:
# 338

# %% [markdown]
# #### 2243 -- Z = 0.007116
# z0 = 0.015
# new...

# %% [markdown]
# ##### Graphs

# %%
### 2243 - Z = 0.007116
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_007 = pd.read_csv('CMD3.6/Cluster 2243/z_0.0071_age6_10.dat', delim_whitespace=True, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_007 = z0_007.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_007[sZ_007['logAge'] == 6].astype(float)
age7 = sZ_007[sZ_007['logAge'] == 7].astype(float)
age8 = sZ_007[sZ_007['logAge'] == 8].astype(float)
age9 = sZ_007[sZ_007['logAge'] == 9].astype(float)
age10= sZ_007[sZ_007['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']


#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.0071', fontsize = 15)
plt.xlabel('B-V [color]', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

#------======= Our Clusters =======--------
# plt.scatter(data_2243['B-V']-0.7, data_2243['V']-17, label = '2243')
plt.scatter(data_2243['B-V']-.3, data_2243['V']-15, label = '2243')

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

plt.grid()
plt.legend(title = 'Years', loc = 'right')
plt.ylim(10,-5)


sZ_007.nunique()
# Out:
# logAge       5
# Bmag      1624
# Vmag      1620
# dtype: int64

# %% [markdown]
# #### Z = 0.005518
# [M/H] = -.44

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_0055 = pd.read_csv('CMD3.6/Cluster 2243/z_0.0055_age6_10.dat', delim_whitespace=True, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_0055 = z0_0055.drop(colNames, axis = 1)


# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_0055[sZ_0055['logAge'] == 6].astype(float)
age7 = sZ_0055[sZ_0055['logAge'] == 7].astype(float)
age8 = sZ_0055[sZ_0055['logAge'] == 8].astype(float)
age9 = sZ_0055[sZ_0055['logAge'] == 9].astype(float)
age10= sZ_0055[sZ_0055['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']



#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.00518', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)

#------======= Our Clusters =======--------
plt.scatter(data_2243['B-V'] ,data_2243['V'], label = '2243', zorder = 1 )
# plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')

# plt.scatter(age6['B-V']+0.7, age6['Vmag']+19, label = '6')
plt.scatter(age7['B-V']+0.7, age7['Vmag']+17, label = '7')
plt.scatter(age8['B-V']+0.7, age8['Vmag']+17, label = '8')
plt.scatter(age9['B-V']+0.4, age9['Vmag']+15, label = '9')
plt.scatter(age10['B-V']-.05, age10['Vmag']+13, label = '10')

plt.grid()
plt.legend(title = 'Years', loc = 'right')
plt.ylim(35,5)


# age6
# Out:
# (35.0, 5.0)

# %% [markdown]
# ### 6231 - Z = 0.019

# %% [markdown]
# #### Distance Modulus
#
# https://webda.physics.muni.cz/cgi-bin/ocl_page.cgi?cluster=ngc+6231
#
# https://webda.physics.muni.cz/navigation.html
#
# ** https://in-the-sky.org/data/object.php?id=NGC6231 **

# %%
# # From (Astronomy & Astrophysics and June I, 1999)
# V = 19
# m_M = 12.9
# b_v = 0.43
# dist = 1190

#----------
# In the sky

mag = 2.6
b_v = 0.23
dist= 1.2e3




#------------------
# SkyLive
Mv = 2.6
mag = data_6231['V'].mean()

# mag - Mv




d = 10**((mag-Mv-0.23+5)/5)
# d = 10**((11.83 + 5)/5)

print('Bolemetric mag\t:' , Mv)
print('Avrg mag\t:' , round(mag,3))
print('Avrg B-V\t:' , round(data_2243['B-V'].mean(),3))
print('m-M \t\t:' ,   round(mag-Mv,3))
print('Distance\t:' , round(d,3) , ' pc')


# print('M-v_avr\t\t:' , round(data_6231['B-V'].mean(),3))
# Out:
# Bolemetric mag	: 2.6
# Avrg mag	: 15.053
# Avrg B-V	: 0.736
# m-M 		: 12.453
# Distance	: 2783.637  pc

# %% [markdown]
# #### Graph

# %%
import pandas as pd
import matplotlib.pyplot as plt

colNames = ['Zini', 'MH', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe',
       'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2',
       'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn',
       'Xo', 'Cexcess', 'Z', 'mbolmag', 'Umag','Rmag', 'Imag',
       'Jmag', 'Hmag', 'Kmag']

z0_019 = pd.read_csv('CMD3.6/Cluster 6231/z_0.019_age6_10.dat', delim_whitespace=True, skiprows=13)
# z0_019_6_5 = pd.read_csv('CMD3.6/Cluster 6231/z_0.019_age6.5.dat', delim_whitespace=True, skiprows=13)
z0_019_7_5 = pd.read_csv('CMD3.6/Cluster 6231/z_0.019_age7.5.dat', delim_whitespace=True, skiprows=13)
# e_6_5 = pd.read_csv('CMD3.6/Cluster 6231/other/age10e6.477.dat', delim_whitespace=True, skiprows=13)


# ------=========Dropping Unused coloms =====-----------
sZ_019 = z0_019.drop(colNames, axis = 1)
# sZ_019_6_5 = z0_019_6_5.drop(colNames, axis = 1)
sZ_019_7_5 = z0_019_7_5.drop(colNames, axis = 1)

# e_6_5 = e_6_5.drop(colNames, axis = 1)

# -------======== Splitting largge DF into Smaller ones ======---------
# ----------------======== According to its age =====---------
age6 = sZ_019[sZ_019['logAge'] == 6 ].astype(float)
age7 = sZ_019[sZ_019['logAge'] == 7 ].astype(float)
age8 = sZ_019[sZ_019['logAge'] == 8 ].astype(float)
age9 = sZ_019[sZ_019['logAge'] == 9 ].astype(float)
age10= sZ_019[sZ_019['logAge'] == 10].astype(float)


#-------======= Calculating B-V =======--------

age6['B-V'] = age6['Bmag'] - age6['Vmag']
age7['B-V'] = age7['Bmag'] - age7['Vmag']
age8['B-V'] = age8['Bmag'] - age8['Vmag']
age9['B-V'] = age9['Bmag'] - age9['Vmag']
age10['B-V'] = age10['Bmag'] - age10['Vmag']

sZ_019_7_5['B-V'] = sZ_019_7_5['Bmag'] - sZ_019_7_5['Vmag']
# sZ_019_6_5['B-V'] = sZ_019_6_5['Bmag'] - sZ_019_6_5['Vmag']
# e_6_5['B-V'] = e_6_5['Bmag'] - e_6_5['Vmag']



#--------========Graphing Data=======----------
plt.figure(figsize=(10,8))
ax = plt.gca()
ax.invert_yaxis()

plt.title('Isochrone for Z = 0.019', fontsize = 15)
plt.xlabel('B-V', fontsize = 15)
plt.ylabel('V_Magnitude', fontsize = 15)


#------======= Our Clusters =======--------
plt.scatter(data_6231['B-V'], data_6231['V'], label = '6231')


# plt.scatter(age6['B-V']+.4, age6['Vmag']+14, label = '6')
# plt.scatter(age7['B-V']+0.4, age7['Vmag']+11.5, label = '7')
# plt.scatter(age8['B-V']+.2, age8['Vmag']+10, label = '8')
# plt.scatter(age9['B-V']+.4, age9['Vmag']+11.5, label = '9')
# plt.scatter(age10['B-V']+.4, age10['Vmag']+11.5, label = '10')

plt.scatter(age6['B-V'], age6['Vmag'], label = '6')
plt.scatter(age7['B-V'], age7['Vmag'], label = '7')
plt.scatter(age8['B-V'], age8['Vmag'], label = '8')
plt.scatter(age9['B-V'], age9['Vmag'], label = '9')
plt.scatter(age10['B-V'], age10['Vmag'], label = '10')

# plt.scatter(sZ_019_6_5['B-V'], sZ_019_6_5['Vmag'], label = '6.5')
# plt.scatter(sZ_019_7_5['B-V']-0.25, sZ_019_7_5['Vmag']-4, label = '7.5')
# plt.scatter(e_6_5['B-V'], e_6_5['Vmag'], label = '3e6.5')


plt.legend(title = 'Age', loc ='right')
plt.grid()
# plt.ylim(30,0)
